# %%
import pandas as pd                                                  #Importem la llibreria pandas (pd).
dades = pd.read_csv('time_series_covid19_deaths_US.csv')  
                                   
dades = pd.DataFrame(dades)  

dades
# Out:
#            UID iso2 iso3  code3     FIPS      Admin2 Province_State  \
# 0     84001001   US  USA    840   1001.0     Autauga        Alabama
# 1     84001003   US  USA    840   1003.0     Baldwin        Alabama
# 2     84001005   US  USA    840   1005.0     Barbour        Alabama
# 3     84001007   US  USA    840   1007.0        Bibb        Alabama
# 4     84001009   US  USA    840   1009.0      Blount        Alabama
# ...        ...  ...  ...    ...      ...         ...            ...
# 3335  84056039   US  USA    840  56039.0       Teton        Wyoming
# 3336  84056041   US  USA    840  56041.0       Uinta        Wyoming
# 3337  84090056   US  USA    840  90056.0  Unassigned        Wyoming
# 3338  84056043   US  USA    840  56043.0    Washakie        Wyoming
# 3339  84056045   US  USA    840  56045.0      Weston        Wyoming
#
#      Country_Region        Lat       Long_  ... 10/7/20  10/8/20  10/9/20  \
# 0                US  32.539527  -86.644082  ...      27       28       28
# ...

# %%
dades = dades.drop(columns = ["UID", "iso2", "iso3", "code3", "FIPS", "Country_Region", "Population", "Combined_Key"])

# %%
dades
# Out:
#           Admin2 Province_State        Lat       Long_  1/22/20  1/23/20  \
# 0        Autauga        Alabama  32.539527  -86.644082        0        0
# 1        Baldwin        Alabama  30.727750  -87.722071        0        0
# 2        Barbour        Alabama  31.868263  -85.387129        0        0
# 3           Bibb        Alabama  32.996421  -87.125115        0        0
# 4         Blount        Alabama  33.982109  -86.567906        0        0
# ...          ...            ...        ...         ...      ...      ...
# 3335       Teton        Wyoming  43.935225 -110.589080        0        0
# 3336       Uinta        Wyoming  41.287818 -110.547578        0        0
# 3337  Unassigned        Wyoming   0.000000    0.000000        0        0
# 3338    Washakie        Wyoming  43.904516 -107.680187        0        0
# 3339      Weston        Wyoming  43.839612 -104.567488        0        0
#
#       1/24/20  1/25/20  1/26/20  1/27/20  ...  10/7/20  10/8/20  10/9/20  \
# ...

# %%
# import pygame
import pygame

# initialize game engine
pygame.init()

window_width=1280
window_height=720

animation_increment=10
clock_tick_rate=20

# Open a window
size = (1280, 720)
screen = pygame.display.set_mode(size)

# Set title to the window
pygame.display.set_caption("Covid USA")

dead=False

clock = pygame.time.Clock()
background_image = pygame.image.load("USA MAP.png").convert()

while(dead==False):
    background_image= pygame.transform.smoothscale(background_image, (1280,720))
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            dead = True

    screen.blit(background_image, [0, 0])

    pygame.display.flip()
    pygame.display.update()
    clock.tick(clock_tick_rate)

# %%
pygame.quit()
